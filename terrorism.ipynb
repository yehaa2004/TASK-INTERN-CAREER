# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Terrorism.csv', encoding = 'ISO-8859-1')

# %%
df
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      1.970000e+11   1970       7     2        NaN         0        NaN
# 1      1.970000e+11   1970       0     0        NaN         0        NaN
# 2      1.970010e+11   1970       1     0        NaN         0        NaN
# 3      1.970010e+11   1970       1     0        NaN         0        NaN
# 4      1.970010e+11   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 92769  2.009070e+11   2009       7    14        NaN         0        NaN
# 92770  2.009070e+11   2009       7    14        NaN         0        NaN
# 92771  2.009070e+11   2009       7    14        NaN         0        NaN
# 92772  2.009070e+11   2009       7    14        NaN         1  1/16/2013
# 92773  2.009070e+11   2009       7    15        NaN         0        NaN
#
#        country         country_txt  region  ...  \
# 0           58  Dominican Republic       2  ...
# 1          130              Mexico       1  ...
# 2          160         Philippines       5  ...
# 3           78              Greece       8  ...
# 4          101               Japan       4  ...
# ...        ...                 ...     ...  ...
# 92769      147             Nigeria      11  ...
# 92770      167              Russia       9  ...
# 92771      205            Thailand       5  ...
# 92772      182             Somalia      11  ...
# 92773      153            Pakistan       6  ...
#
#                                                 addnotes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 92769                                                NaN
# 92770                                                NaN
# 92771                                                NaN
# 92772  On 8/25/2009, one hostage escaped. The second ...
# 92773                                                NaN
#
#                                                   scite1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 92769  National Counterterrorism Center, "One Oil Pip...
# 92770  National Counterterrorism Center, "One Residen...
# 92771  Straits Times, "Muslim Villager Killed in Patt...
# 92772  The Guardian, "French Security Advisors Kidnap...
# 92773                                                NaN
#
#                                                   scite2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 92769  Africa News, "Nigeria; Militants Spurn Amnesty...
# 92770  Jane's Intelligence, "Pro-Rebel Website Claims...
# 92771  National Counterterrorism Center, "One Civilia...
# 92772  Agence France Presse, "Somali Gunmen Abduct Tw...
# 92773                                                NaN
#
#                                                   scite3  dbsource  INT_LOG  \
# 0                                                    NaN      PGIS      0.0
# 1                                                    NaN      PGIS      0.0
# 2                                                    NaN      PGIS     -9.0
# 3                                                    NaN      PGIS     -9.0
# 4                                                    NaN      PGIS     -9.0
# ...                                                  ...       ...      ...
# 92769  allAfrica.com, "Nigeria: MEND's Attack on Atla...      ISVG      0.0
# 92770                                                NaN      ISVG     -9.0
# 92771                                                NaN      ISVG     -9.0
# 92772  "French agent 'executed' by al-Shabaab," Al Ja...      ISVG      0.0
# 92773                                                NaN       NaN      NaN
#
#        INT_IDEO INT_MISC INT_ANY  related
# 0           0.0      0.0     0.0      NaN
# 1           1.0      1.0     1.0      NaN
# 2          -9.0      1.0     1.0      NaN
# 3          -9.0      1.0     1.0      NaN
# 4          -9.0      1.0     1.0      NaN
# ...         ...      ...     ...      ...
# 92769       1.0      1.0     1.0      NaN
# 92770      -9.0      0.0    -9.0      NaN
# 92771      -9.0      0.0    -9.0      NaN
# 92772       1.0      1.0     1.0      NaN
# 92773       NaN      NaN     NaN      NaN
#
# [92774 rows x 135 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92774 entries, 0 to 92773
# Columns: 135 entries, eventid to related
# dtypes: float64(59), int64(18), object(58)
# memory usage: 95.6+ MB

# %%
# Displaying the columns
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Concise summary of dataset

df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  9.277400e+04  92774.000000  92774.000000  92774.000000  92774.000000
# mean   1.991807e+11   1991.742600      6.394755     15.287915      0.029836
# std    9.873866e+08      9.874654      3.376698      8.827767      0.170135
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.984090e+11   1984.000000      4.000000      8.000000      0.000000
# 50%    1.991050e+11   1991.000000      6.000000     15.000000      0.000000
# 75%    1.999100e+11   1999.000000      9.000000     23.000000      0.000000
# max    2.009070e+11   2009.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  92774.000000  92774.000000  88746.000000  8.874500e+04  92772.000000
# mean     140.615765      6.220913     20.599882 -9.677170e+02      1.436748
# std      128.871210      3.140207     22.436421  2.893106e+05      1.074555
# min        4.000000      1.000000    -53.154613 -8.618590e+07      1.000000
# 25%       61.000000      3.000000      6.929089 -7.385384e+01      1.000000
# 50%      101.000000      6.000000     26.020885  1.134652e+01      1.000000
# 75%      177.000000      9.000000     36.763763  4.565449e+01      1.000000
# max     1003.000000     12.000000     74.633553  1.793667e+02      5.000000
#
#        ...     ransomamt   ransomamtus    ransompaid  ransompaidus  \
# count  ...  9.100000e+02  1.480000e+02  3.510000e+02    143.000000
# mean   ...  3.206286e+06  5.571798e+05  7.129398e+05    863.503497
# std    ...  3.460008e+07  2.359172e+06  3.393208e+06   5686.002671
# min    ... -9.900000e+01 -9.900000e+01 -9.900000e+01    -99.000000
# 25%    ...  0.000000e+00  0.000000e+00 -9.900000e+01      0.000000
# 50%    ...  1.000000e+04  0.000000e+00  0.000000e+00      0.000000
# 75%    ...  5.000000e+05  0.000000e+00  5.507100e+04      0.000000
# max    ...  1.000000e+09  2.000000e+07  4.100000e+07  48000.000000
#
#        hostkidoutcome    nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     3810.000000  3226.000000  92773.000000  92773.000000  92773.000000
# mean         4.309449   -17.828580     -4.119129     -4.077285      0.116435
# std          2.076393    61.103989      4.541230      4.596613      0.742344
# min          1.000000   -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000   -99.000000     -9.000000     -9.000000      0.000000
# 50%          4.000000     1.000000      0.000000      0.000000      0.000000
# 75%          7.000000     2.000000      0.000000      0.000000      0.000000
# max          7.000000   856.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  92773.000000
# mean      -3.362034
# std        4.610439
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 77 columns]

# %%
# Checking for null values
df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    92493
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       82735
# Length: 135, dtype: int64

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                     'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                     'nwound': 'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                     'weaptype1_txt':'Weapon_type','motive':'Motive'
                    },inplace=True)

# %%
# As we have many columns, we take the columns that are necessary for analysis
df = df[['eventid','Year','Month','Day','Country','Region','state','city','latitude','longitude','AttackType','Killed','Wounded',
            'Target','Summary','Group','Target_type','Weapon_type','Motive','success']]

# %%
df.head()
# Out:
#         eventid  Year  Month  Day             Country  \
# 0  1.970000e+11  1970      7    2  Dominican Republic
# 1  1.970000e+11  1970      0    0              Mexico
# 2  1.970010e+11  1970      1    0         Philippines
# 3  1.970010e+11  1970      1    0              Greece
# 4  1.970010e+11  1970      1    0               Japan
#
#                         Region    state           city   latitude   longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#                        AttackType  Killed  Wounded                   Target  \
# 0                   Assassination     1.0      0.0             Julio Guzman
# 1     Hostage Taking (Kidnapping)     0.0      0.0  Nadine Chaval, daughter
# 2                   Assassination     1.0      0.0                 Employee
# 3               Bombing/Explosion     NaN      NaN             U.S. Embassy
# 4  Facility/Infrastructure Attack     NaN      NaN           U.S. Consulate
#
#   Summary                               Group                  Target_type  \
# 0     NaN                              MANO-D  Private Citizens & Property
# 1     NaN  23rd of September Communist League      Government (Diplomatic)
# 2     NaN                             Unknown          Journalists & Media
# 3     NaN                             Unknown      Government (Diplomatic)
# 4     NaN                             Unknown      Government (Diplomatic)
#
#   Weapon_type Motive  success
# 0     Unknown    NaN        1
# 1     Unknown    NaN        1
# 2     Unknown    NaN        1
# 3  Explosives    NaN        1
# 4  Incendiary    NaN        1

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# state            419
# city             252
# latitude        4028
# longitude       4029
# AttackType         0
# Killed          6495
# Wounded         9757
# Target           617
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# Motive         66670
# success            0
# dtype: int64

# %%
df1= df.dropna(axis=0)

# %%
df.head(5)
# Out:
#         eventid  Year  Month  Day             Country  \
# 0  1.970000e+11  1970      7    2  Dominican Republic
# 1  1.970000e+11  1970      0    0              Mexico
# 2  1.970010e+11  1970      1    0         Philippines
# 3  1.970010e+11  1970      1    0              Greece
# 4  1.970010e+11  1970      1    0               Japan
#
#                         Region    state           city   latitude   longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#                        AttackType  Killed  Wounded                   Target  \
# 0                   Assassination     1.0      0.0             Julio Guzman
# 1     Hostage Taking (Kidnapping)     0.0      0.0  Nadine Chaval, daughter
# 2                   Assassination     1.0      0.0                 Employee
# 3               Bombing/Explosion     NaN      NaN             U.S. Embassy
# 4  Facility/Infrastructure Attack     NaN      NaN           U.S. Consulate
#
#   Summary                               Group                  Target_type  \
# 0     NaN                              MANO-D  Private Citizens & Property
# 1     NaN  23rd of September Communist League      Government (Diplomatic)
# 2     NaN                             Unknown          Journalists & Media
# 3     NaN                             Unknown      Government (Diplomatic)
# 4     NaN                             Unknown      Government (Diplomatic)
#
#   Weapon_type Motive  success
# 0     Unknown    NaN        1
# 1     Unknown    NaN        1
# 2     Unknown    NaN        1
# 3  Explosives    NaN        1
# 4  Incendiary    NaN        1

# %%
year_attacks = df.groupby('Year').size().reset_index(name='count')

# %%
sns.lineplot(x='Year', y='count', data=year_attacks, color='blue')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title("Terrorism Attacks Trends from 1970 to 2017")
plt.show()

# %%
plt.subplots(figsize=(12,6))
top=df['Country'].value_counts()[:10].to_frame().reset_index()
top.columns= ['Country','Attacks_Counts']
sns.barplot(x='Country',y='Attacks_Counts', data= top, palette='magma')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
region_attacks= df.Region.value_counts().to_frame().reset_index()
region_attacks.columns = ['Region', 'Total Attacks']
plt.subplots(figsize=(15,7))
sns.barplot(x=region_attacks['Total Attacks'], y=region_attacks.Region, edgecolor=sns.color_palette('dark',10),orient='h')
plt.title('Number of Total Attacks in Each Region')
plt.show()

# %%
# Attacks basaed on the region 

region_attack_counts = df.groupby(['Region', 'AttackType']).size().reset_index()
region_attack_counts.columns = ['Region', 'AttackType', 'Attack Count']

region = df.Region.unique()

# %%
# Attack type specific to region wise

def region_attack_type(region):
    sns.set(style="whitegrid")
    
    for i in region:
        selected_region = i

        # Filter the data for the selected region
        selected_region_data = region_attack_counts[region_attack_counts['Region'] == selected_region]

        # Create the bar plot
        plt.figure(figsize=(10, 6))
        sns.barplot(data=selected_region_data, x='AttackType', y='Attack Count', palette="viridis")
        plt.title(f'Terrorist Attack Types in {selected_region}')
        plt.xlabel('Attack Type')
        plt.ylabel('Number of Attacks')
        plt.xticks(rotation=75)
        plt.tight_layout()

        plt.show()

region_attack_type(region)

# %%
groups = df[['AttackType','Group','Weapon_type','Target_type']]

# %%
groups
# Out:
#                            AttackType  \
# 0                       Assassination
# 1         Hostage Taking (Kidnapping)
# 2                       Assassination
# 3                   Bombing/Explosion
# 4      Facility/Infrastructure Attack
# ...                               ...
# 92769               Bombing/Explosion
# 92770                   Assassination
# 92771                   Armed Assault
# 92772     Hostage Taking (Kidnapping)
# 92773               Bombing/Explosion
#
#                                                    Group Weapon_type  \
# 0                                                 MANO-D     Unknown
# 1                     23rd of September Communist League     Unknown
# 2                                                Unknown     Unknown
# 3                                                Unknown  Explosives
# 4                                                Unknown  Incendiary
# ...                                                  ...         ...
# 92769  Movement for the Emancipation of the Niger Del...  Explosives
# 92770                                            Unknown  Explosives
# 92771                                            Unknown    Firearms
# 92772                                         Al-Shabaab    Firearms
# 92773                                            Unknown  Explosives
#
#                        Target_type
# 0      Private Citizens & Property
# 1          Government (Diplomatic)
# 2              Journalists & Media
# 3          Government (Diplomatic)
# 4          Government (Diplomatic)
# ...                            ...
# 92769                    Utilities
# 92770                       Police
# 92771  Private Citizens & Property
# 92772         Government (General)
# 92773  Private Citizens & Property
#
# [92774 rows x 4 columns]

# %%
group_counts = groups['Group'].value_counts()
sort = group_counts.sort_values(ascending=False)

# Select the top 5 most frequent groups
sort = sort.iloc[1:]
top_5 = sort.head(5)

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.barplot(x=top_5.index, y=top_5.values, palette="viridis")
plt.title('Top Terrorist Attack Groups')
plt.xlabel('Attack Count')
plt.ylabel('Group')
plt.xticks(rotation = 90)
plt.show()

# %%
corr_data = df.groupby('Country').agg({'Country': 'count', 'Killed': 'sum', 'Wounded': 'sum'})
corr_data.columns = ['Total Attacks', 'Total Killed', 'Total Wounded']
corr_data.reset_index(inplace=True)

corr_data['Casualties'] = corr_data['Total Killed']+corr_data['Total Wounded']
corr_data.drop(['Total Killed', 'Total Wounded'],axis = 1,inplace = True)

# %%
corr_data
# Out:
#          Country  Total Attacks  Casualties
# 0    Afghanistan           1808     11256.0
# 1        Albania             69       165.0
# 2        Algeria           2462     19194.0
# 3        Andorra              1         0.0
# 4         Angola            488      5067.0
# ..           ...            ...         ...
# 199        Yemen            193       674.0
# 200   Yugoslavia            203       400.0
# 201        Zaire             50       535.0
# 202       Zambia             60       132.0
# 203     Zimbabwe             92       371.0
#
# [204 rows x 3 columns]

# %%
noa = df.groupby('Year').size().reset_index(name='count')
noa
# Out:
#     Year  count
# 0   1970    651
# 1   1971    471
# 2   1972    568
# 3   1973    473
# 4   1974    581
# 5   1975    740
# 6   1976    923
# 7   1977   1319
# 8   1978   1526
# 9   1979   2662
# 10  1980   2662
# 11  1981   2586
# 12  1982   2544
# 13  1983   2870
# 14  1984   3495
# 15  1985   2915
# 16  1986   2860
# 17  1987   3183
# 18  1988   3721
# 19  1989   4324
# 20  1990   3887
# 21  1991   4683
# 22  1992   5071
# 23  1994   3456
# 24  1995   3081
# 25  1996   3058
# 26  1997   3197
# 27  1998    934
# 28  1999   1395
# 29  2000   1814
# 30  2001   1906
# 31  2002   1333
# 32  2003   1278
# 33  2004   1166
# 34  2005   2017
# 35  2006   2758
# 36  2007   3242
# 37  2008   4804
# 38  2009   2620

# %%
# Calculating the total number of attacks
sum_of_attacks = noa['count'].sum()
print('Total number of attacks all over the world:', sum_of_attacks)
# Out:
# Total number of attacks all over the world: 92774

# %%
# Calculating the success rate
succ = df.groupby(['success']).size().reset_index(name='count')
succ['percentage'] =  succ['count']/sum_of_attacks *100
succ
# Out:
#    success  count  percentage
# 0        0   7511    8.096018
# 1        1  85263   91.903982

# %%
sns.barplot(x = 'success', y = 'percentage', data=succ)
plt.title("Outcome of Terrorist Attacks over the World")
plt.xlabel("Outcome")
# Out:
# Text(0.5, 0, 'Outcome')

# %%
India = df[(df['Country'] == 'India')]
India.head(5)
# Out:
#            eventid  Year  Month  Day Country      Region        state  \
# 1186  1.972020e+11  1972      2   22   India  South Asia        Delhi
# 2764  1.975010e+11  1975      1    2   India  South Asia        Bihar
# 3857  1.976050e+11  1976      5   26   India  South Asia        Delhi
# 5327  1.977090e+11  1977      9   28   India  South Asia  Maharashtra
# 7337  1.979010e+11  1979      1   13   India  South Asia        Assam
#
#             city   latitude  longitude         AttackType  Killed  Wounded  \
# 1186   New Delhi  28.585836  77.153336          Hijacking     0.0      0.0
# 2764  Samastipur  25.863042  85.781004  Bombing/Explosion     4.0      0.0
# 3857   New Delhi  28.585836  77.153336  Bombing/Explosion     0.0      0.0
# 5327      Bombay  19.075984  72.877656          Hijacking     0.0      0.0
# 7337     Unknown  26.200605  92.937574      Armed Assault     NaN      NaN
#
#                                      Target  \
# 1186                                  B-747
# 2764  Lalit Narayan Mishra and a legislator
# 3857                      New Delhi airport
# 5327                                   DC-8
# 7337                                 patrol
#
#                                                 Summary  \
# 1186                                                NaN
# 2764  1/2/1975: The Indian Railway Minister, Lalit N...
# 3857                                                NaN
# 5327                                                NaN
# 7337                                                NaN
#
#                         Group           Target_type Weapon_type   Motive  \
# 1186             Palestinians   Airports & Aircraft  Explosives      NaN
# 2764             Ananda Marga  Government (General)  Explosives  Unknown
# 3857                  Unknown   Airports & Aircraft  Explosives      NaN
# 5327  Japanese Red Army (JRA)   Airports & Aircraft    Firearms      NaN
# 7337              Naga People                Police    Firearms      NaN
#
#       success
# 1186        1
# 2764        1
# 3857        1
# 5327        1
# 7337        1

# %%
#how many number of attacks where there in India
India_attacks = India['eventid'].count()
print('There were',India_attacks ,'attacks in India.')
# Out:
# There were 5326 attacks in India.

# %%
India_success = India.groupby('success').size().reset_index(name='count')
India_success['percentage'] = India_success['count'] / India_attacks * 100
India_success
# Out:
#    success  count  percentage
# 0        0    380     7.13481
# 1        1   4946    92.86519

# %%
sns.barplot(x='success', y='percentage', data = India_success, color='green')
plt.title("Outcome of Terrorist Attacks in India")
plt.xlabel("Outcome")
# Out:
# Text(0.5, 0, 'Outcome')

# %%
attack_types_India = India.groupby(['AttackType','success']).size().reset_index(name='count')
attack_types_India
# Out:
#                              AttackType  success  count
# 0                         Armed Assault        0     37
# 1                         Armed Assault        1   1542
# 2                         Assassination        0    109
# 3                         Assassination        1    808
# 4                     Bombing/Explosion        0    213
# 5                     Bombing/Explosion        1   1880
# 6        Facility/Infrastructure Attack        0      5
# 7        Facility/Infrastructure Attack        1    203
# 8                             Hijacking        0      4
# 9                             Hijacking        1     24
# 10  Hostage Taking (Barricade Incident)        1      6
# 11          Hostage Taking (Kidnapping)        0      5
# 12          Hostage Taking (Kidnapping)        1    287
# 13                      Unarmed Assault        1     41
# 14                              Unknown        0      7
# 15                              Unknown        1    155

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='AttackType', y='count', hue='success', data=attack_types_India, color = "blue")
plt.title("Facility ")
# Out:
# Text(0.5, 1.0, 'Facility ')

# %%
#number of kills
nkills_India = India.groupby('AttackType')[['Killed']].sum().reset_index()
nkills_India
# Out:
#                             AttackType  Killed
# 0                        Armed Assault  7370.0
# 1                        Assassination  1749.0
# 2                    Bombing/Explosion  4876.0
# 3       Facility/Infrastructure Attack    75.0
# 4                            Hijacking    27.0
# 5  Hostage Taking (Barricade Incident)   119.0
# 6          Hostage Taking (Kidnapping)   280.0
# 7                      Unarmed Assault    11.0
# 8                              Unknown   724.0

# %%
plt.figure(figsize=(30,10))
sns.barplot(x='AttackType', y='Killed', data=nkills_India)
# Out:
# <Axes: xlabel='AttackType', ylabel='Killed'>
